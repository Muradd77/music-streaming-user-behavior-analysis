# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Asus\Downloads\spotify_user_behavior_realistic_50000_rows.csv")
df
# Out:
#        user_id    country  age signup_date   subscription_type  \
# 0            1     France   25  2021-08-19         Premium Duo
# 1            2  Indonesia   20  2022-06-06      Premium Family
# 2            3      Italy   53  2024-01-04  Premium Individual
# 3            4      Italy   48  2018-08-26  Premium Individual
# 4            5  Australia   18  2020-05-29                Free
# ...        ...        ...  ...         ...                 ...
# 49995    49996      India   33  2022-09-23                Free
# 49996    49997      Italy   35  2023-11-17      Premium Family
# 49997    49998     Brazil   33  2024-11-14  Premium Individual
# 49998    49999        USA   43  2021-05-31                Free
# 49999    50000  Indonesia   38  2024-07-05                Free
#
#       subscription_status  months_inactive  inactive_3_months_flag  \
# 0                  Active                0                       0
# 1                  Active                0                       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   user_id                         50000 non-null  int64
#  1   country                         50000 non-null  object
#  2   age                             50000 non-null  int64
#  3   signup_date                     50000 non-null  object
#  4   subscription_type               50000 non-null  object
#  5   subscription_status             50000 non-null  object
#  6   months_inactive                 50000 non-null  int64
#  7   inactive_3_months_flag          50000 non-null  int64
#  8   ad_interaction                  50000 non-null  object
#  9   ad_conversion_to_subscription   50000 non-null  object
#  10  music_suggestion_rating_1_to_5  50000 non-null  int64
#  11  avg_listening_hours_per_week    50000 non-null  float64
# ...

# %%
df.describe()
# Out:
#             user_id           age  months_inactive  inactive_3_months_flag  \
# count  50000.000000  50000.000000     50000.000000            50000.000000
# mean   25000.500000     38.010280         1.533020                0.222460
# std    14433.901067     12.984989         1.952082                0.415903
# min        1.000000     16.000000         0.000000                0.000000
# 25%    12500.750000     27.000000         0.000000                0.000000
# 50%    25000.500000     38.000000         1.000000                0.000000
# 75%    37500.250000     49.000000         2.000000                0.000000
# max    50000.000000     60.000000        18.000000                1.000000
#
#        music_suggestion_rating_1_to_5  avg_listening_hours_per_week  \
# count                    50000.000000                  50000.000000
# mean                         3.644100                      9.988986
# std                          1.114424                      3.968927
# ...

# %%
df.isnull().sum()
# Out:
# user_id                           0
# country                           0
# age                               0
# signup_date                       0
# subscription_type                 0
# subscription_status               0
# months_inactive                   0
# inactive_3_months_flag            0
# ad_interaction                    0
# ad_conversion_to_subscription     0
# music_suggestion_rating_1_to_5    0
# avg_listening_hours_per_week      0
# favorite_genre                    0
# most_liked_feature                0
# desired_future_feature            0
# primary_device                    0
# playlists_created                 0
# avg_skips_per_day                 0
# dtype: int64

# %%
df['signup_date'] = pd.to_datetime(df['signup_date'])
df['days_since_signup'] = (pd.Timestamp.today() - df['signup_date']).dt.days

# %%
df
# Out:
#        user_id    country  age signup_date   subscription_type  \
# 0            1     France   25  2021-08-19         Premium Duo
# 1            2  Indonesia   20  2022-06-06      Premium Family
# 2            3      Italy   53  2024-01-04  Premium Individual
# 3            4      Italy   48  2018-08-26  Premium Individual
# 4            5  Australia   18  2020-05-29                Free
# ...        ...        ...  ...         ...                 ...
# 49995    49996      India   33  2022-09-23                Free
# 49996    49997      Italy   35  2023-11-17      Premium Family
# 49997    49998     Brazil   33  2024-11-14  Premium Individual
# 49998    49999        USA   43  2021-05-31                Free
# 49999    50000  Indonesia   38  2024-07-05                Free
#
#       subscription_status  months_inactive  inactive_3_months_flag  \
# 0                  Active                0                       0
# 1                  Active                0                       0
# ...

# %%
df.drop('signup_date', axis=1, inplace=True)

# %%
df['subscription_status'].value_counts()
# Out:
# subscription_status
# Active      42109
# Inactive     7891
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(x='subscription_status', data=df)
plt.show()

# %%
sns.histplot(df['age'], kde=True)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %%
df.drop('user_id', axis=1, inplace=True)

# %%
sns.histplot(df['playlists_created'], kde=True)
plt.show()

# %%
sns.histplot(df['avg_skips_per_day'], kde=True)
plt.show()

# %%
sns.boxplot(x='subscription_type', y='avg_listening_hours_per_week', data=df)
plt.show()

# %%
sns.scatterplot(x='age', y='avg_listening_hours_per_week', hue='subscription_status', data=df)
# Out:
# <Axes: xlabel='age', ylabel='avg_listening_hours_per_week'>

# %%
df['subscription_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='subscription_type'>

# %%
sns.countplot(x='favorite_genre', hue='subscription_status', data=df)
# Out:
# <Axes: xlabel='favorite_genre', ylabel='count'>

# %%
df
# Out:
#          country  age   subscription_type subscription_status  \
# 0         France   25         Premium Duo              Active
# 1      Indonesia   20      Premium Family              Active
# 2          Italy   53  Premium Individual              Active
# 3          Italy   48  Premium Individual              Active
# 4      Australia   18                Free              Active
# ...          ...  ...                 ...                 ...
# 49995      India   33                Free              Active
# 49996      Italy   35      Premium Family              Active
# 49997     Brazil   33  Premium Individual              Active
# 49998        USA   43                Free              Active
# 49999  Indonesia   38                Free            Inactive
#
#        months_inactive  inactive_3_months_flag ad_interaction  \
# 0                    0                       0             No
# 1                    0                       0            Yes
# ...

# %%
cat_col = df.select_dtypes(include='object').columns
cat_col = cat_col.drop('subscription_status')
print(cat_col)
# Out:
# Index(['country', 'subscription_type', 'ad_interaction',
#        'ad_conversion_to_subscription', 'favorite_genre', 'most_liked_feature',
#        'desired_future_feature', 'primary_device'],
#       dtype='object')

# %%
for col in cat_col:
    plt.figure(figsize=(8,4))
    sns.countplot(x=col, data=df)
    plt.title(f'{col} distribution')
    plt.xticks(rotation=45)
    plt.show()

# %%
for col in cat_col:
    plt.figure(figsize=(8,4))
    sns.countplot(x=col, hue='subscription_status', data=df)
    plt.title(f'{col} vs subscription_status')
    plt.xticks(rotation=45)
    plt.show()

# %%
df_encoded = pd.get_dummies(df)
print(df_encoded)
# Out:
#        age  months_inactive  inactive_3_months_flag  \
# 0       25                0                       0
# 1       20                0                       0
# 2       53                0                       0
# 3       48                1                       0
# 4       18                0                       0
# ...    ...              ...                     ...
# 49995   33                2                       0
# 49996   35                0                       0
# 49997   33                0                       0
# 49998   43                0                       0
# 49999   38                3                       1
#
#        music_suggestion_rating_1_to_5  avg_listening_hours_per_week  \
# 0                                   4                         10.13
# 1                                   5                         11.63
# 2                                   3                          9.50
# ...

# %%
categorical_cols = df.select_dtypes(include='object').columns.tolist()
X = pd.get_dummies(df, columns=categorical_cols)

from sklearn.preprocessing import LabelEncoder
y = LabelEncoder().fit_transform(df['subscription_status'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

# prediction
y_pred = model.predict(X_test)

# əsas metriclər
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)

# detailed report
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# confusion matrix
print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     12692
#            1       1.00      1.00      1.00      2308
#
#     accuracy                           1.00     15000
#    macro avg       1.00      1.00      1.00     15000
# weighted avg       1.00      1.00      1.00     15000
#
#
# Confusion Matrix:
#
# [[12692     0]
#  [    0  2308]]
